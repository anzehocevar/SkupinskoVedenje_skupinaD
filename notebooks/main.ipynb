# %% [markdown]
# # Initialization

# %%
from cb25d.notebook import init

init()  # This should always be called first to set the directory and set up autoreload.

# %% [markdown]
# # Slow preprocessing

# %%
# This is a placeholder to show how a notebook should be structured.
# Write some stuff to disk here.

# %% [markdown]
# # Analysis

# %%
# Now you can use the results from the previous section by loading them from disk.
# This means that the next time you have to rerun the notebook, you don't have to run the slow preprocessing again if you haven't changed that part of the codebase.

# %% [markdown]
# # Fancy plots

# %%
# ...
