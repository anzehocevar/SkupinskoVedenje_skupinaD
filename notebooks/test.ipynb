# %%
from cb25d.interactive import run_interactive_simulation
from cb25d.notebook import init
from cb25d.simulation_impl_sinewave import (
    SimulationImplSinewave,
    SimulationRendererSinewave,
)

init()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_interactive_simulation(
    SimulationImplSinewave(0),
    SimulationRendererSinewave(),
)
